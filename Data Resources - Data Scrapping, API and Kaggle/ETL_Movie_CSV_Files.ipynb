# %%
import pandas as pd
import datetime as dt
from decimal import Decimal

# %%
movie_list2 = pd.read_csv('output/clean_movie_list_df2.csv')
movie_list2
# Out:
#                                                 name rating      genre  score  \
# 0                                        The Shining      R      Drama    8.4
# 1                                    The Blue Lagoon      R  Adventure    5.8
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                          Airplane!     PG     Comedy    7.7
# 4                                         Caddyshack      R     Comedy    7.3
# ...                                              ...    ...        ...    ...
# 7663                                    More to Life      0      Drama    3.1
# 7664                                     Dream Round      0     Comedy    4.7
# 7665                                   Saving Mbango      0      Drama    5.7
# 7666                                    It's Just Us      0      Drama    0.0
# 7667                                       Tee em el      0     Horror    5.7
#
# ...

# %%
#clean dataframe
movie_list2 = pd.DataFrame(movie_list2.rename(columns={'name':'title','rating':'movie_rating','genre': 'genre_name', 'score':'imdb_rating',
                                                      'star':'actors', 'budget':'box_office', 'Run': 'run_time', 'released':'release_date'}))
movie_list2
# Out:
#                                                title movie_rating genre_name  \
# 0                                        The Shining            R      Drama
# 1                                    The Blue Lagoon            R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back           PG     Action
# 3                                          Airplane!           PG     Comedy
# 4                                         Caddyshack            R     Comedy
# ...                                              ...          ...        ...
# 7663                                    More to Life            0      Drama
# 7664                                     Dream Round            0     Comedy
# 7665                                   Saving Mbango            0      Drama
# 7666                                    It's Just Us            0      Drama
# 7667                                       Tee em el            0     Horror
#
# ...

# %%
movie_list2 = movie_list2[["title", "movie_rating", "release_date", "genre_name", 'director','writer','actors','imdb_rating','box_office','run_time']]
movie_list2
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
#export to csv
movie_list2.to_csv ('output/clean_movie_list_df_completed.csv', header=True, index=False)
movie_list2
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
movie_list3 = pd.read_csv('output/clean_movie_list_df_2122.csv')
movie_list3
# Out:
#      movie_id                                        title movie_rating  \
# 0           0                      Spider-Man: No Way Home        PG-13
# 1           1    Shang-Chi and the Legend of the Ten Rings        PG-13
# 2           2                  Venom: Let There Be Carnage        PG-13
# 3           3                                  Black Widow        PG-13
# 4           4                            F9: The Fast Saga        PG-13
# ..        ...                                          ...          ...
# 257       257  The Beatles: Get Back - The Rooftop Concert        PG-13
# 258       258                             The Tiger Rising           PG
# 259       259                                   Bone Clean            0
# 260       260                Sparks - The Ken Sparks Story            0
# 261       261                         Found Wandering Lost            0
#
#     release_date                  genre_name               Director  \
# ...

# %%
#clean dataframe
movie_list3 = pd.DataFrame(movie_list2.rename(columns={'Director':'director', 'Writer':'writer', 'Actors':'actors',
                                                       'BoxOffice':'box_office', 'runtime': 'run_time'}))
movie_list3
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
#export to csv
movie_list3.to_csv ('output/clean_movie_list_df_2122_completed.csv', header=True, index=False)
movie_list3
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
movie_list4 = pd.read_csv('output/clean_movie_list_df_completed.csv')
movie_list4
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
#export to csv
movie_list5 = pd.read_csv('output/clean_movie_list_df_2122_completed.csv')
movie_list5
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
# to append dataframe
completed_movie_list_df = movie_list4.append(movie_list5)
completed_movie_list_df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
#export final csv
completed_movie_list_df.to_csv ('output/completed_movie_list_df.csv', header=True, index=False)
completed_movie_list_df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7663                                    More to Life            0
# 7664                                     Dream Round            0
# 7665                                   Saving Mbango            0
# 7666                                    It's Just Us            0
# 7667                                       Tee em el            0
#
#      release_date genre_name         director                   writer  \
# 0      1980-06-13      Drama  Stanley Kubrick             Stephen King
# ...

# %%
completed_movie_list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15336 entries, 0 to 7667
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         15336 non-null  object
#  1   movie_rating  15336 non-null  object
#  2   release_date  15332 non-null  object
#  3   genre_name    15336 non-null  object
#  4   director      15336 non-null  object
#  5   writer        15336 non-null  object
#  6   actors        15336 non-null  object
#  7   imdb_rating   15336 non-null  float64
#  8   box_office    15336 non-null  float64
#  9   run_time      15336 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 1.3+ MB

# %%
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy 
from sqlalchemy import create_engine

from config import username, password

# %%
from sqlalchemy import create_engine
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/movies_db')
connection = engine.connect()

# %%
completed_movie_list_df.to_sql(name='movie_list', con=engine, if_exists='append', index=True)

# %%
pd.read_sql_query('select * from movie_list', con=engine).head()
# Out:
#    index                                           title movie_rating  \
# 0      0                                     The Shining            R
# 1      1                                 The Blue Lagoon            R
# 2      2  Star Wars: Episode V - The Empire Strikes Back           PG
# 3      3                                       Airplane!           PG
# 4      4                                      Caddyshack            R
#
#   release_date genre_name         director                   writer  \
# 0   1980-06-13      Drama  Stanley Kubrick             Stephen King
# 1   1980-07-02  Adventure   Randal Kleiser  Henry De Vere Stacpoole
# 2   1980-06-20     Action   Irvin Kershner           Leigh Brackett
# 3   1980-07-02     Comedy     Jim Abrahams             Jim Abrahams
# 4   1980-07-25     Comedy     Harold Ramis       Brian Doyle-Murray
#
#            actors  imdb_rating  box_office  run_time
# 0  Jack Nicholson          8.4  19000000.0     146.0
# ...
