# %%
import pandas as pd
import datetime as dt
from decimal import Decimal

# %%
df = pd.read_csv('final_movie_list.csv')
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean          NaN
# 7928                   Sparks - The Ken Sparks Story          NaN
# 7929                            Found Wandering Lost          NaN
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon             NaN
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah             NaN
# 7927              Keegan Joyce, Gemma Bird Matheson             NaN
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin             NaN
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette             NaN
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0      NaN
# 1      58853106.0     104.0   1980-07-02         0.0      NaN
# 2     538375067.0     124.0   1980-06-20         0.0      NaN
# 3      83453539.0      88.0   1980-07-02         0.0      NaN
# 4      39846344.0      98.0   1980-07-25         0.0      NaN
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 13 columns]

# %%
df['language'] = df['language'].fillna('NA')
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean          NaN
# 7928                   Sparks - The Ken Sparks Story          NaN
# 7929                            Found Wandering Lost          NaN
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon             NaN
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah             NaN
# 7927              Keegan Joyce, Gemma Bird Matheson             NaN
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin             NaN
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette             NaN
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 13 columns]

# %%
df['country'] = df['country'].fillna('NA')
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean          NaN
# 7928                   Sparks - The Ken Sparks Story          NaN
# 7929                            Found Wandering Lost          NaN
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 13 columns]

# %%
df['meta_score'] = df['meta_score'].fillna('0')
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean          NaN
# 7928                   Sparks - The Ken Sparks Story          NaN
# 7929                            Found Wandering Lost          NaN
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 13 columns]

# %%
df['release_date'].isnull().sum()
# Out:
# 0

# %%
df['release_date']=df['release_date'].fillna('1900-01-01')
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean          NaN
# 7928                   Sparks - The Ken Sparks Story          NaN
# 7929                            Found Wandering Lost          NaN
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 13 columns]

# %%
df['release_date'].isnull().sum()
# Out:
# 0

# %%
df['release_date'] = pd.to_datetime(df['release_date']).dt.date
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean          NaN
# 7928                   Sparks - The Ken Sparks Story          NaN
# 7929                            Found Wandering Lost          NaN
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 13 columns]

# %%
df['movie_rating']=df['movie_rating'].fillna('NA')
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean           NA
# 7928                   Sparks - The Ken Sparks Story           NA
# 7929                            Found Wandering Lost           NA
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 13 columns]

# %%
df['movie_id'] = range(1, len(df) + 1)
df
# Out:
#                                                title movie_rating  \
# 0                                        The Shining            R
# 1                                    The Blue Lagoon            R
# 2     Star Wars: Episode V - The Empire Strikes Back           PG
# 3                                          Airplane!           PG
# 4                                         Caddyshack            R
# ...                                              ...          ...
# 7925     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926                                The Tiger Rising           PG
# 7927                                      Bone Clean           NA
# 7928                   Sparks - The Ken Sparks Story           NA
# 7929                            Found Wandering Lost           NA
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language  movie_id
# 0      46998772.0     146.0   1980-06-13         0.0       NA         1
# 1      58853106.0     104.0   1980-07-02         0.0       NA         2
# 2     538375067.0     124.0   1980-06-20         0.0       NA         3
# 3      83453539.0      88.0   1980-07-02         0.0       NA         4
# 4      39846344.0      98.0   1980-07-25         0.0       NA         5
# ...           ...       ...          ...         ...      ...       ...
# 7925     793669.0      65.0   2022-01-30         0.0  English      7926
# 7926          0.0     102.0   2022-02-03        33.0  English      7927
# 7927          0.0       0.0   1900-01-01         0.0  English      7928
# 7928          0.0      88.0   2022-01-07         0.0  English      7929
# 7929          0.0      99.0   2022-01-25         0.0        0      7930
#
# [7930 rows x 14 columns]

# %%
#create movie table setup
movie = pd.DataFrame(df[['movie_id','title','movie_rating','genre_name','imdb_rating','director',
                        'writer','actors','country','box_office','run_time','release_date','meta_score','language']])
movie
# Out:
#       movie_id                                           title movie_rating  \
# 0            1                                     The Shining            R
# 1            2                                 The Blue Lagoon            R
# 2            3  Star Wars: Episode V - The Empire Strikes Back           PG
# 3            4                                       Airplane!           PG
# 4            5                                      Caddyshack            R
# ...        ...                                             ...          ...
# 7925      7926     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926      7927                                The Tiger Rising           PG
# 7927      7928                                      Bone Clean           NA
# 7928      7929                   Sparks - The Ken Sparks Story           NA
# 7929      7930                            Found Wandering Lost           NA
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 14 columns]

# %%
#export to csv
movie.to_csv ('final_movie_list2.csv', header=True, index=False)
movie
# Out:
#       movie_id                                           title movie_rating  \
# 0            1                                     The Shining            R
# 1            2                                 The Blue Lagoon            R
# 2            3  Star Wars: Episode V - The Empire Strikes Back           PG
# 3            4                                       Airplane!           PG
# 4            5                                      Caddyshack            R
# ...        ...                                             ...          ...
# 7925      7926     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926      7927                                The Tiger Rising           PG
# 7927      7928                                      Bone Clean           NA
# 7928      7929                   Sparks - The Ken Sparks Story           NA
# 7929      7930                            Found Wandering Lost           NA
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon              NA
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah              NA
# 7927              Keegan Joyce, Gemma Bird Matheson              NA
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin              NA
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette              NA
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0       NA
# 1      58853106.0     104.0   1980-07-02         0.0       NA
# 2     538375067.0     124.0   1980-06-20         0.0       NA
# 3      83453539.0      88.0   1980-07-02         0.0       NA
# 4      39846344.0      98.0   1980-07-25         0.0       NA
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 14 columns]

# %%
#create movie table setup
movie2 = pd.DataFrame(df[['movie_id','title','movie_rating', 'release_date', 'run_time', 'meta_score', 'imdb_rating', 'box_office']])
movie2
# Out:
#       movie_id                                           title movie_rating  \
# 0            1                                     The Shining            R
# 1            2                                 The Blue Lagoon            R
# 2            3  Star Wars: Episode V - The Empire Strikes Back           PG
# 3            4                                       Airplane!           PG
# 4            5                                      Caddyshack            R
# ...        ...                                             ...          ...
# 7925      7926     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926      7927                                The Tiger Rising           PG
# 7927      7928                                      Bone Clean           NA
# 7928      7929                   Sparks - The Ken Sparks Story           NA
# 7929      7930                            Found Wandering Lost           NA
#
#      release_date  run_time  meta_score  imdb_rating   box_office
# 0      1980-06-13     146.0         0.0          8.4   46998772.0
# 1      1980-07-02     104.0         0.0          5.8   58853106.0
# 2      1980-06-20     124.0         0.0          8.7  538375067.0
# 3      1980-07-02      88.0         0.0          7.7   83453539.0
# 4      1980-07-25      98.0         0.0          7.3   39846344.0
# ...           ...       ...         ...          ...          ...
# 7925   2022-01-30      65.0         0.0          0.0     793669.0
# 7926   2022-02-03     102.0        33.0          5.8          0.0
# 7927   1900-01-01       0.0         0.0          0.0          0.0
# 7928   2022-01-07      88.0         0.0          0.0          0.0
# 7929   2022-01-25      99.0         0.0          5.8          0.0
#
# [7930 rows x 8 columns]

# %%
#export to csv
movie2.to_csv ('movie.csv', header=True, index=False)

movie2.head()
# Out:
#    movie_id                                           title movie_rating  \
# 0         1                                     The Shining            R
# 1         2                                 The Blue Lagoon            R
# 2         3  Star Wars: Episode V - The Empire Strikes Back           PG
# 3         4                                       Airplane!           PG
# 4         5                                      Caddyshack            R
#
#   release_date  run_time  meta_score  imdb_rating   box_office
# 0   1980-06-13     146.0         0.0          8.4   46998772.0
# 1   1980-07-02     104.0         0.0          5.8   58853106.0
# 2   1980-06-20     124.0         0.0          8.7  538375067.0
# 3   1980-07-02      88.0         0.0          7.7   83453539.0
# 4   1980-07-25      98.0         0.0          7.3   39846344.0

# %%
#create movie table setup
genre = pd.DataFrame(df[['movie_id','genre_name']]).rename(columns={'movie_id':'genre_id'})
#export to csv
genre.to_csv ('genre.csv', header=True, index=False)

genre.head()
# Out:
#    genre_id genre_name
# 0         1      Drama
# 1         2  Adventure
# 2         3     Action
# 3         4     Comedy
# 4         5     Comedy

# %%
#create movie table setup
movie_genre_juction = movie2.join(genre, how='outer')
movie_genre_juction = pd.DataFrame(movie_genre_juction[['movie_id','genre_id']])

#export to csv
genre.to_csv ('movie_genre_juction.csv', header=True, index=False)

movie_genre_juction.head()
# Out:
#    movie_id  genre_id
# 0         1         1
# 1         2         2
# 2         3         3
# 3         4         4
# 4         5         5

# %%
df2 = pd.read_csv('final_movie_list2.csv')
df2
# Out:
#       movie_id                                           title movie_rating  \
# 0            1                                     The Shining            R
# 1            2                                 The Blue Lagoon            R
# 2            3  Star Wars: Episode V - The Empire Strikes Back           PG
# 3            4                                       Airplane!           PG
# 4            5                                      Caddyshack            R
# ...        ...                                             ...          ...
# 7925      7926     The Beatles: Get Back - The Rooftop Concert        PG-13
# 7926      7927                                The Tiger Rising           PG
# 7927      7928                                      Bone Clean          NaN
# 7928      7929                   Sparks - The Ken Sparks Story          NaN
# 7929      7930                            Found Wandering Lost          NaN
#
#            genre_name  imdb_rating         director  \
# 0               Drama          8.4  Stanley Kubrick
# 1           Adventure          5.8   Randal Kleiser
# 2              Action          8.7   Irvin Kershner
# 3              Comedy          7.7     Jim Abrahams
# 4              Comedy          7.3     Harold Ramis
# ...               ...          ...              ...
# 7925            Music          0.0    Peter Jackson
# 7926           Family          5.8   Ray Giarratana
# 7927     Short, Drama          0.0     Katy Maudlin
# 7928        Biography          0.0      Jeff Joslin
# 7929  Drama, Thriller          5.8  Nicholaus James
#
#                               writer  \
# 0                       Stephen King
# 1            Henry De Vere Stacpoole
# 2                     Leigh Brackett
# 3                       Jim Abrahams
# 4                 Brian Doyle-Murray
# ...                              ...
# 7925                               0
# 7926  Kate DiCamillo, Ray Giarratana
# 7927                     Morgan Rose
# 7928                  Ciera Danielle
# 7929   Nicholaus James, James Thomas
#
#                                              actors         country  \
# 0                                    Jack Nicholson  United Kingdom
# 1                                    Brooke Shields   United States
# 2                                       Mark Hamill   United States
# 3                                       Robert Hays   United States
# 4                                       Chevy Chase   United States
# ...                                             ...             ...
# 7925      The Beatles, George Harrison, John Lennon             NaN
# 7926  Dennis Quaid, Katharine McPhee, Queen Latifah             NaN
# 7927              Keegan Joyce, Gemma Bird Matheson             NaN
# 7928     Chad Sparks, Chanda Childress, Jeff Joslin             NaN
# 7929       Eric Bowles, Dylan Brown, Jessi Burkette             NaN
#
#        box_office  run_time release_date  meta_score language
# 0      46998772.0     146.0   1980-06-13         0.0      NaN
# 1      58853106.0     104.0   1980-07-02         0.0      NaN
# 2     538375067.0     124.0   1980-06-20         0.0      NaN
# 3      83453539.0      88.0   1980-07-02         0.0      NaN
# 4      39846344.0      98.0   1980-07-25         0.0      NaN
# ...           ...       ...          ...         ...      ...
# 7925     793669.0      65.0   2022-01-30         0.0  English
# 7926          0.0     102.0   2022-02-03        33.0  English
# 7927          0.0       0.0   1900-01-01         0.0  English
# 7928          0.0      88.0   2022-01-07         0.0  English
# 7929          0.0      99.0   2022-01-25         0.0        0
#
# [7930 rows x 14 columns]

# %%
# create dfs for tables
role_df = pd.DataFrame({"role_id": [0,1,2], "role": ["Director", "Writer", "Actor"]})
person_df = pd.DataFrame({"person_id": [], "person": []})
movie_role_person_df = pd.DataFrame(columns=["movie", "person", "role"])

# %%
# set indexes
role_df.set_index(['role_id'], inplace=True)
person_df.set_index(["person_id"], inplace=True)
role_df
# Out:
#              role
# role_id
# 0        Director
# 1          Writer
# 2           Actor

# %%
person_df.head()
# Out:
# Empty DataFrame
# Columns: [person]
# Index: []

# %%
# iterate through movie_df
for index, row in df2.iterrows():
    # split out all people with roles
    directors = row["director"].split(", ")
    writers = row["writer"].split(", ")
    actors = row["actors"].split(", ")


    for director in directors:
        # check if person in person_df
        if director not in person_df["person"].values:
            new_person_row = {"person": director}
            person_df = person_df.append(new_person_row, ignore_index=True)
        # add new junction row
        new_junction_row = {"movie": row["movie_id"], "role": 0, "person": person_df.index[person_df["person"] == director].tolist()}
        movie_role_person_df = movie_role_person_df.append(new_junction_row, ignore_index=True)
        
    for writer in writers:
        # check if person in person_df
        if writer not in person_df["person"].values:
            new_person_row = {"person": writer}
            person_df = person_df.append(new_person_row, ignore_index=True)
        # add new junction row
        new_junction_row = {"movie": row["movie_id"], "role": 1, "person": person_df.index[person_df["person"] == writer].tolist()}
        movie_role_person_df = movie_role_person_df.append(new_junction_row, ignore_index=True)

    for actor in actors:
        # check if person in person_df
        if actor not in person_df["person"].values:
            new_person_row = {"person": actor}
            person_df = person_df.append(new_person_row, ignore_index=True)
        # add new junction row
        new_junction_row = {"movie": row["movie_id"], "role": 2, "person": person_df.index[person_df["person"] == actor].tolist()}
        movie_role_person_df = movie_role_person_df.append(new_junction_row, ignore_index=True)
# Out:
# /var/folders/ff/04lnt98n62z2m6h1qpf6gglr0000gn/T/ipykernel_99190/1198171055.py:11: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if director not in person_df["person"].values:

# %%
person2 = person_df.rename(columns={'person':'name'})
person2.index.name = "person_id"
person2.head()
# Out:
#                               name
# person_id
# 0                  Stanley Kubrick
# 1                     Stephen King
# 2                   Jack Nicholson
# 3                   Randal Kleiser
# 4          Henry De Vere Stacpoole

# %%
# converts person column from list type to string type
movie_role_person_df['person']  = [','.join(map(str, row)) for row in movie_role_person_df['person']]

# %%
movie_role_person_df2 = movie_role_person_df.rename(columns={'movie':'movie_id', 'person':'person_id', 'role':'role_id'})
movie_role_person_df2
# Out:
#       movie_id person_id role_id
# 0            1         0       0
# 1            1         1       1
# 2            1         2       2
# 3            2         3       0
# 4            2         4       1
# ...        ...       ...     ...
# 24513     7930      9545       1
# 24514     7930      9546       1
# 24515     7930      9547       2
# 24516     7930      8493       2
# 24517     7930      9548       2
#
# [24518 rows x 3 columns]

# %%
role_df.to_csv("role_table.csv")
person2.to_csv("person_table.csv")
movie_role_person_df2.to_csv("movie_role_person_junction_table.csv", index=False)

# %%
role_df
# Out:
#              role
# role_id
# 0        Director
# 1          Writer
# 2           Actor

# %%
person2
# Out:
#                               name
# person_id
# 0                  Stanley Kubrick
# 1                     Stephen King
# 2                   Jack Nicholson
# 3                   Randal Kleiser
# 4          Henry De Vere Stacpoole
# ...                            ...
# 9544              Chanda Childress
# 9545               Nicholaus James
# 9546                  James Thomas
# 9547                   Eric Bowles
# 9548                Jessi Burkette
#
# [9549 rows x 1 columns]

# %%
movie_role_person_df
# Out:
#       movie person role
# 0         1      0    0
# 1         1      1    1
# 2         1      2    2
# 3         2      3    0
# 4         2      4    1
# ...     ...    ...  ...
# 24513  7930   9545    1
# 24514  7930   9546    1
# 24515  7930   9547    2
# 24516  7930   8493    2
# 24517  7930   9548    2
#
# [24518 rows x 3 columns]
