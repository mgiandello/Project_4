# %%
import pandas as pd
import datetime as dt
from decimal import Decimal

# %%
load_df = pd.read_csv('output/Original_CSV_files/complete_movie_list_df_2021_2022.csv')
load_df = load_df.drop(['Unnamed: 0','Unnamed: 0.1','Production'], axis=1)
load_df
# Out:
#                                            Title  Year  Rated     Released  \
# 0                        Spider-Man: No Way Home  2021  PG-13  17 Dec 2021
# 1      Shang-Chi and the Legend of the Ten Rings  2021  PG-13  03 Sep 2021
# 2                    Venom: Let There Be Carnage  2021  PG-13  01 Oct 2021
# 3                                    Black Widow  2021  PG-13  09 Jul 2021
# 4                              F9: The Fast Saga  2021  PG-13  25 Jun 2021
# ..                                           ...   ...    ...          ...
# 257  The Beatles: Get Back - The Rooftop Concert  2022  PG-13  30 Jan 2022
# 258                             The Tiger Rising  2022     PG  03 Feb 2022
# 259                                   Bone Clean  2022      0            0
# 260                Sparks - The Ken Sparks Story  2022      0  07 Jan 2022
# 261                         Found Wandering Lost  2022      0  25 Jan 2022
#
#      Runtime                       Genre               Director  \
# ...

# %%
load_df = load_df.fillna(0)
load_df
# Out:
#                                            Title  Year  Rated     Released  \
# 0                        Spider-Man: No Way Home  2021  PG-13  17 Dec 2021
# 1      Shang-Chi and the Legend of the Ten Rings  2021  PG-13  03 Sep 2021
# 2                    Venom: Let There Be Carnage  2021  PG-13  01 Oct 2021
# 3                                    Black Widow  2021  PG-13  09 Jul 2021
# 4                              F9: The Fast Saga  2021  PG-13  25 Jun 2021
# ..                                           ...   ...    ...          ...
# 257  The Beatles: Get Back - The Rooftop Concert  2022  PG-13  30 Jan 2022
# 258                             The Tiger Rising  2022     PG  03 Feb 2022
# 259                                   Bone Clean  2022      0            0
# 260                Sparks - The Ken Sparks Story  2022      0  07 Jan 2022
# 261                         Found Wandering Lost  2022      0  25 Jan 2022
#
#      Runtime                       Genre               Director  \
# ...

# %%
load_df2=load_df['Runtime'].str.split(' ', expand=True)
load_df2
# Out:
#        0     1
# 0    148   min
# 1    132   min
# 2     97   min
# 3    134   min
# 4    143   min
# ..   ...   ...
# 257   65   min
# 258  102   min
# 259    0  None
# 260   88   min
# 261   99   min
#
# [262 rows x 2 columns]

# %%
load_df2 = load_df2.rename(columns={0: "a", 1: "c"})
load_df2
# Out:
#        a     c
# 0    148   min
# 1    132   min
# 2     97   min
# 3    134   min
# 4    143   min
# ..   ...   ...
# 257   65   min
# 258  102   min
# 259    0  None
# 260   88   min
# 261   99   min
#
# [262 rows x 2 columns]

# %%
# to append dataframe
load_df3 = load_df.join(load_df2)
load_df3
# Out:
#                                            Title  Year  Rated     Released  \
# 0                        Spider-Man: No Way Home  2021  PG-13  17 Dec 2021
# 1      Shang-Chi and the Legend of the Ten Rings  2021  PG-13  03 Sep 2021
# 2                    Venom: Let There Be Carnage  2021  PG-13  01 Oct 2021
# 3                                    Black Widow  2021  PG-13  09 Jul 2021
# 4                              F9: The Fast Saga  2021  PG-13  25 Jun 2021
# ..                                           ...   ...    ...          ...
# 257  The Beatles: Get Back - The Rooftop Concert  2022  PG-13  30 Jan 2022
# 258                             The Tiger Rising  2022     PG  03 Feb 2022
# 259                                   Bone Clean  2022      0            0
# 260                Sparks - The Ken Sparks Story  2022      0  07 Jan 2022
# 261                         Found Wandering Lost  2022      0  25 Jan 2022
#
#      Runtime                       Genre               Director  \
# ...

# %%
load_df4=load_df3.drop(['c', 'Runtime'], axis=1)
load_df4
# Out:
#                                            Title  Year  Rated     Released  \
# 0                        Spider-Man: No Way Home  2021  PG-13  17 Dec 2021
# 1      Shang-Chi and the Legend of the Ten Rings  2021  PG-13  03 Sep 2021
# 2                    Venom: Let There Be Carnage  2021  PG-13  01 Oct 2021
# 3                                    Black Widow  2021  PG-13  09 Jul 2021
# 4                              F9: The Fast Saga  2021  PG-13  25 Jun 2021
# ..                                           ...   ...    ...          ...
# 257  The Beatles: Get Back - The Rooftop Concert  2022  PG-13  30 Jan 2022
# 258                             The Tiger Rising  2022     PG  03 Feb 2022
# 259                                   Bone Clean  2022      0            0
# 260                Sparks - The Ken Sparks Story  2022      0  07 Jan 2022
# 261                         Found Wandering Lost  2022      0  25 Jan 2022
#
#                           Genre               Director  \
# ...

# %%
load_df5 = load_df4.rename(columns={'a':'Runtime'})
load_df5
# Out:
#                                            Title  Year  Rated     Released  \
# 0                        Spider-Man: No Way Home  2021  PG-13  17 Dec 2021
# 1      Shang-Chi and the Legend of the Ten Rings  2021  PG-13  03 Sep 2021
# 2                    Venom: Let There Be Carnage  2021  PG-13  01 Oct 2021
# 3                                    Black Widow  2021  PG-13  09 Jul 2021
# 4                              F9: The Fast Saga  2021  PG-13  25 Jun 2021
# ..                                           ...   ...    ...          ...
# 257  The Beatles: Get Back - The Rooftop Concert  2022  PG-13  30 Jan 2022
# 258                             The Tiger Rising  2022     PG  03 Feb 2022
# 259                                   Bone Clean  2022      0            0
# 260                Sparks - The Ken Sparks Story  2022      0  07 Jan 2022
# 261                         Found Wandering Lost  2022      0  25 Jan 2022
#
#                           Genre               Director  \
# ...

# %%
#converting to proper types
load_df5['Released'] = pd.to_datetime(load_df['Released'], errors='coerce')
load_df5.Title = load_df.Title.astype('string')
load_df5.Rated = load_df.Rated.astype('string')
load_df5.Runtime = load_df.Runtime.astype('string')
#load_df['Runtime'] = load_df['Runtime'].str.split(' ', 1, expand=True)
load_df5.Genre = load_df.Genre.astype('string')
load_df5.Director = load_df.Director.astype('string')
load_df5.Writer = load_df.Writer.astype('string')
load_df5.Actors = load_df.Actors.astype('string')
load_df5.Director = load_df.Director.astype('string')
load_df5.Language = load_df.Language.astype('string')
load_df5['BoxOffice'] = load_df['BoxOffice'].replace('[\$,]', '', regex=True).astype(int)
load_df5.dtypes
# Out:
# Title                 string
# Year                   int64
# Rated                 string
# Released      datetime64[ns]
# Genre                 string
# Director              string
# Writer                string
# Actors                string
# Language              string
# Metascore            float64
# imdbRating           float64
# BoxOffice              int64
# Runtime               string
# dtype: object

# %%
converted_df = load_df5
converted_df
# Out:
#                                            Title  Year  Rated   Released  \
# 0                        Spider-Man: No Way Home  2021  PG-13 2021-12-17
# 1      Shang-Chi and the Legend of the Ten Rings  2021  PG-13 2021-09-03
# 2                    Venom: Let There Be Carnage  2021  PG-13 2021-10-01
# 3                                    Black Widow  2021  PG-13 2021-07-09
# 4                              F9: The Fast Saga  2021  PG-13 2021-06-25
# ..                                           ...   ...    ...        ...
# 257  The Beatles: Get Back - The Rooftop Concert  2022  PG-13 2022-01-30
# 258                             The Tiger Rising  2022     PG 2022-02-03
# 259                                   Bone Clean  2022      0        NaT
# 260                Sparks - The Ken Sparks Story  2022      0 2022-01-07
# 261                         Found Wandering Lost  2022      0 2022-01-25
#
#                           Genre               Director  \
# ...

# %%
#export to csv
converted_df.to_csv ('output/Original_CSV_files/clean_movie_list_df_2021_2022.csv', header=True, index=False)
converted_df
# Out:
#                                            Title  Year  Rated   Released  \
# 0                        Spider-Man: No Way Home  2021  PG-13 2021-12-17
# 1      Shang-Chi and the Legend of the Ten Rings  2021  PG-13 2021-09-03
# 2                    Venom: Let There Be Carnage  2021  PG-13 2021-10-01
# 3                                    Black Widow  2021  PG-13 2021-07-09
# 4                              F9: The Fast Saga  2021  PG-13 2021-06-25
# ..                                           ...   ...    ...        ...
# 257  The Beatles: Get Back - The Rooftop Concert  2022  PG-13 2022-01-30
# 258                             The Tiger Rising  2022     PG 2022-02-03
# 259                                   Bone Clean  2022      0        NaT
# 260                Sparks - The Ken Sparks Story  2022      0 2022-01-07
# 261                         Found Wandering Lost  2022      0 2022-01-25
#
#                           Genre               Director  \
# ...

# %%
movie_list2 = pd.read_csv('output/Original_CSV_files/movies.csv')
movie_list2
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#clean dataframe
#movie_list2 = pd.DataFrame(movie_list2.rename(columns={'name':'title','rating':'movie_rating','genre':'genre_name','year':'year','released':'release_date',
#'score':'imdb_rating','votes':'votes', 'director':'Director', 'writer':'Writer', 'star':'Actors', 'country':'country', 'budget':'BoxOffice', 'gross':'gross',
#'company':'company','runtime':'runtime',}))

#clean dataframe
#converted_df = pd.DataFrame(converted_df.rename(columns={'Title':'title','Rated':'movie_rating','Released':'release_date',
#'Runtime':'runtime', 'Genre': 'genre_name', 'Metascore':'metascore','imdbRating':'imdb_rating'}))

#movie_list2

# %%
movie_list2 = movie_list2.fillna(0)
movie_list2
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
release_date=movie_list2['released'].str.split('(', expand=True)
release_date
# Out:
#                       0               1
# 0        June 13, 1980   United States)
# 1         July 2, 1980   United States)
# 2        June 20, 1980   United States)
# 3         July 2, 1980   United States)
# 4        July 25, 1980   United States)
# ...                 ...             ...
# 7663  October 23, 2020   United States)
# 7664  February 7, 2020   United States)
# 7665    April 27, 2020        Cameroon)
# 7666   October 1, 2020   United States)
# 7667   August 19, 2020   United States)
#
# [7668 rows x 2 columns]

# %%
release_date2 = release_date.rename(columns={0: "a", 1: "c"})
release_date2
# Out:
#                       a               c
# 0        June 13, 1980   United States)
# 1         July 2, 1980   United States)
# 2        June 20, 1980   United States)
# 3         July 2, 1980   United States)
# 4        July 25, 1980   United States)
# ...                 ...             ...
# 7663  October 23, 2020   United States)
# 7664  February 7, 2020   United States)
# 7665    April 27, 2020        Cameroon)
# 7666   October 1, 2020   United States)
# 7667   August 19, 2020   United States)
#
# [7668 rows x 2 columns]

# %%
# to append dataframe
complete_movie_list_df = movie_list2.join(release_date2)
complete_movie_list_df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
complete_movie_list_df2=complete_movie_list_df.drop(['c', 'released'], axis=1)
complete_movie_list_df2
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
complete_movie_list_df3 = complete_movie_list_df2.rename(columns={'a':'released','runtime':'Runtime'})
complete_movie_list_df3
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
#converting to proper types
complete_movie_list_df3['released'] = pd.to_datetime(complete_movie_list_df3['released'], errors='coerce')
complete_movie_list_df3.name = complete_movie_list_df3.name.astype('string')
complete_movie_list_df3.rating = complete_movie_list_df3.rating.astype('string')
complete_movie_list_df3.Runtime = complete_movie_list_df3.Runtime.astype('string')
#load_df['Runtime'] = load_df['Runtime'].str.split(' ', 1, expand=True)
complete_movie_list_df3.genre = complete_movie_list_df3.genre.astype('string')
complete_movie_list_df3.writer = complete_movie_list_df3.writer.astype('string')
complete_movie_list_df3.star = complete_movie_list_df3.star.astype('string')
complete_movie_list_df3.director = complete_movie_list_df3.director.astype('string')
#complete_movie_list_df3['budget'] = complete_movie_list_df3['budget'].replace('[\$,]', '', regex=True).astype(int)
complete_movie_list_df3.dtypes
# Out:
# name                string
# rating              string
# genre               string
# year                 int64
# score              float64
# votes              float64
# director            string
# writer              string
# star                string
# country             object
# budget             float64
# gross              float64
# company             object
# Runtime             string
# released    datetime64[ns]
# dtype: object

# %%
complete_movie_list_df4 = complete_movie_list_df3.drop(['votes','gross','company'], axis=1)
complete_movie_list_df4
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
#export to csv
complete_movie_list_df4.to_csv ('output/Original_CSV_files/clean_movie_list.csv', header=True, index=False)
complete_movie_list_df4
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
complete_movie_list_df5 = pd.read_csv('Archieve/clean_movie_list.csv')
complete_movie_list_df5
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/ff/04lnt98n62z2m6h1qpf6gglr0000gn/T/ipykernel_96626/822418490.py in <module>
# ----> 1 complete_movie_list_df5 = pd.read_csv('Archieve/clean_movie_list.csv')
#       2 complete_movie_list_df5
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#2021-2022
converted_df.columns
# Out:
# Index(['Title', 'Year', 'Rated', 'Released', 'Genre', 'Director', 'Writer',
#        'Actors', 'Language', 'Metascore', 'imdbRating', 'BoxOffice',
#        'Runtime'],
#       dtype='object')

# %%
#1980-2020
complete_movie_list_df5.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'score', 'director', 'writer',
#        'star', 'country', 'budget', 'Runtime', 'released'],
#       dtype='object')

# %%
#joining data
frames = [complete_movie_list_df5,converted_df]

movie_df= pd.concat(frames)

# %%
movie_df.head(100)
# Out:
#                                               name rating      genre    year  \
# 0                                      The Shining      R      Drama  1980.0
# 1                                  The Blue Lagoon      R  Adventure  1980.0
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980.0
# 3                                        Airplane!     PG     Comedy  1980.0
# 4                                       Caddyshack      R     Comedy  1980.0
# ..                                             ...    ...        ...     ...
# 95                            Escape from New York      R     Action  1981.0
# 96                                   The Evil Dead  NC-17     Horror  1981.0
# 97                                         Porky's      R     Comedy  1981.0
# 98                                        Blow Out      R      Crime  1981.0
# 99                             Clash of the Titans     PG     Action  1981.0
#
# ...

# %%
movie_df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'score', 'director', 'writer',
#        'star', 'country', 'budget', 'Runtime', 'released', 'Title', 'Year',
#        'Rated', 'Released', 'Genre', 'Director', 'Writer', 'Actors',
#        'Language', 'Metascore', 'imdbRating', 'BoxOffice'],
#       dtype='object')

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7930 entries, 0 to 261
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        7668 non-null   object
#  1   rating      7668 non-null   object
#  2   genre       7668 non-null   object
#  3   year        7668 non-null   float64
#  4   score       7668 non-null   float64
#  5   director    7668 non-null   object
#  6   writer      7668 non-null   object
#  7   star        7668 non-null   object
#  8   country     7668 non-null   object
#  9   budget      7668 non-null   float64
#  10  Runtime     7930 non-null   object
#  11  released    7666 non-null   object
#  12  Title       262 non-null    string
#  13  Year        262 non-null    float64
#  14  Rated       262 non-null    string
#  15  Released    257 non-null    datetime64[ns]
#  16  Genre       262 non-null    string
#  17  Director    262 non-null    string
# ...

# %%
#checking number of null values in each column 
movie_df.isnull().sum()
# Out:
# name           262
# rating         262
# genre          262
# year           262
# score          262
# director       262
# writer         262
# star           262
# country        262
# budget         262
# Runtime          0
# released       264
# Title         7668
# Year          7668
# Rated         7668
# Released      7673
# Genre         7668
# Director      7668
# Writer        7668
# Actors        7668
# Language      7668
# Metascore     7668
# imdbRating    7668
# BoxOffice     7668
# dtype: int64

# %%
#Taking some more extra features from kaggel dataset which are not present in OMDB dataset
complete_movie_list_df5=complete_movie_list_df5[['name', 'genre', 'star', 'budget']]
complete_movie_list_df5=complete_movie_list_df5.rename(columns={'name':'Title'})

# %%
complete_movie_list_df5.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'score', 'director', 'writer',
#        'star', 'country', 'budget', 'Runtime', 'released'],
#       dtype='object')

# %%
#merging OMDB dataset with extra features
movie_df=movie_df.merge(complete_movie_list_df5, on='Title' ,how='inner')
movie_df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ff/04lnt98n62z2m6h1qpf6gglr0000gn/T/ipykernel_85583/4229747740.py in <module>
#       1 #merging OMDB dataset with extra features
# ----> 2 movie_df=movie_df.merge(complete_movie_list_df5, on='Title' ,how='inner')
#       3 movie_df.shape
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
